# %%
# Import necessary libraries:
import gurobipy as gp
from gurobipy import GRB
import numpy as np

# %% [markdown]
# The task is, given a set of five products produced by seven machines - each with their own efficiencies and maximal usage - produce the mix of products maximizing profit.
#
# The first model solves this problem for a single-period. The second model introduces multiple periods and the ability to store products between periods, which differ in machine availability and demand per product.

# %%
# Single period model
m_j = gp.Model("ProductMixProblem")
m_j.ModelSense = GRB.MAXIMIZE
m_j.setParam('TimeLimit', 1000)

# Initialize decision variables, representing products and expected profit per product produced

## TorqueMaster
TM = m_j.addVar(vtype=GRB.CONTINUOUS, name="TorqueMaster", lb=0, obj=10)
## CryoLock
CL = m_j.addVar(vtype=GRB.CONTINUOUS, name="CryoLock", lb=0, obj=6)
## Axial-Flex
AF = m_j.addVar(vtype=GRB.CONTINUOUS, name="Axial-Flex", lb=0, obj=8)
## HydroForge
HF = m_j.addVar(vtype=GRB.CONTINUOUS, name="HydroForge", lb=0, obj=4)
## ThermaCore
TC = m_j.addVar(vtype=GRB.CONTINUOUS, name="ThermaCore", lb=0, obj=11)
# MagnoRail
MR = m_j.addVar(vtype=GRB.CONTINUOUS, name="MagnoRail", lb=0, obj=9)
## VibeShield
VS = m_j.addVar(vtype=GRB.CONTINUOUS, name="VibeShield", lb=0, obj=3)

# Initialize demand constraints for January as upper limits per product.
# Note that I am explicitly adding these as opposed to setting a ub parameter in the decision variables
# so that they are easier to adjust and analyze.

## TorqueMaster
m_j.addConstr(TM <= 500, name="TorqueMaster Demand")
## CryoLock
m_j.addConstr(CL <= 1000, name="CryoLock Demand")
## Axial-Flex
m_j.addConstr(AF <= 300, name="Axial-Flex Demand")
## HydroForge
m_j.addConstr(HF <= 300, name="HydroForge Demand")
## ThermaCore
m_j.addConstr(TC <= 800, name="ThermaCore Demand")
## MagnoRail
m_j.addConstr(MR <= 200, name="MagnoRail Demand")
## VibeShield
m_j.addConstr(VS <= 100, name="VibeShield Demand")

# The below expressions encode the amount of time required of each machine to produce one of each given product. nX refers to the number of available machines in January.

## Grinding
G = (0.5*TM + 0.7*CL + 0*AF + 0*HF + 0.3*TC + 0.2*MR + 0.5*VS)
nG = 3
## Vertical Drilling
VD = (0.1*TM + 0.2*CL + 0*AF + 0.3*HF + 0*TC + 0.6*MR + 0*VS)
nVD = 2
## Horizontal Drilling
HD = (0.2*TM + 0*CL + 0.8*AF + 0*HF + 0*TC + 0*MR + 0.6*VS)
nHD = 3
## Boring
B = (0.05*TM + 0.03*CL + 0*AF + 0.07*HF + 0.1*TC + 0*MR + 0.08*VS)
nB = 1
## Planing
P = (0*TM + 0*CL + 0.01*AF + 0*HF + 0.05*TC + 0*MR + 0.05*VS)
nP = 1

# The total time constraint is the number of working hours across 24 days.
hours = 16
working_days = 24
LC = hours * working_days

# Initialize time constraint as the amount each machine can be utilized, adjusted by the number of available machines.
m_j.addConstr(G <= LC * nG, name="G Time Constraint")
m_j.addConstr(VD <= LC * nVD, name="VD Time Constraint")
m_j.addConstr(HD <= LC * nHD, name="HD Time Constraint")
m_j.addConstr(B <= LC * nB, name="B Time Constraint")
m_j.addConstr(P <= LC * nP, name="P Time Constraint")

# Run model and display the optimal mix of products.
m_j.update()
m_j.display()
m_j.optimize()

[print(f'Optimal # of {var.VarName}s: {var.X}') for var in m_j.getVars()]
print(f'Optimal profit: ${m_j.ObjVal:0.2f}')
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2710302
# Academic license - for non-commercial use only - expires 2026-09-18
# Set parameter TimeLimit to value 1000
# Maximize
# 10.0 TorqueMaster + 6.0 CryoLock + 8.0 Axial-Flex + 4.0 HydroForge + 11.0 ThermaCore
# + 9.0 MagnoRail + 3.0 VibeShield
# Subject To
#   TorqueMaster Demand: TorqueMaster <= 500
#   CryoLock Demand: CryoLock <= 1000
#   Axial-Flex Demand: Axial-Flex <= 300
#   HydroForge Demand: HydroForge <= 300
#   ThermaCore Demand: ThermaCore <= 800
#   MagnoRail Demand: MagnoRail <= 200
#   VibeShield Demand: VibeShield <= 100
# G Time Constraint: 0.5 TorqueMaster + 0.7 CryoLock + 0.3 ThermaCore + 0.2 MagnoRail +
#  0.5 VibeShield <= 1152
# VD Time Constraint: 0.1 TorqueMaster + 0.2 CryoLock + 0.3 HydroForge + 0.6 MagnoRail <=
#  768
#   HD Time Constraint: 0.2 TorqueMaster + 0.8 Axial-Flex + 0.6 VibeShield <= 1152
# B Time Constraint: 0.05 TorqueMaster + 0.03 CryoLock + 0.07 HydroForge + 0.1 ThermaCore
#  + 0.08 VibeShield <= 384
#   P Time Constraint: 0.01 Axial-Flex + 0.05 ThermaCore + 0.05 VibeShield <= 384
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-12800H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  1000
#
# Optimize a model with 12 rows, 7 columns and 27 nonzeros
# Model fingerprint: 0xf58d6724
# Coefficient statistics:
#   Matrix range     [1e-02, 1e+00]
#   Objective range  [3e+00, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+02, 1e+03]
# Presolve removed 11 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 5 columns, 5 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.5440000e+04   3.475000e+02   0.000000e+00      0s
#        1    2.4531429e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.453142857e+04
# Optimal # of TorqueMasters: 500.0
# Optimal # of CryoLocks: 888.5714285714287
# Optimal # of Axial-Flexs: 300.0
# Optimal # of HydroForges: 300.0
# Optimal # of ThermaCores: 800.0
# Optimal # of MagnoRails: 200.0
# Optimal # of VibeShields: 0.0
# Optimal profit: $24531.43
# C:\Users\harri\AppData\Local\Temp\ipykernel_26228\467124266.py:74: DeprecationWarning: Model.display() is deprecated
#   m_j.display()

# %%
# January sensitivity analysis
# for var in m_j.getVars():
#     print(f'Variable: {var.varName}, Optimal Value = {var.x}, (LB,UB) = ({var.lb}, {var.ub}), Reduced cost = {var.RC}, Coeff = {var.obj}, Obj coeff range = ({var.SAObjLow: .3f}, {var.SAObjUp: .3f})')
    
for c in m_j.getConstrs():
    print(f'Constraint: {c.ConstrName}, RHS = {c.RHS}, slack = {c.slack}, Limits = ({c.SARHSLow}, {c.SARHSUp}, Shadow Price = {(c.Pi)})')
    
# By running a sensitivity analysis, I can see that the only binding constraint is on grinding time constraint. That constraint has a positive shadow
# price, so I would like more grinders. Through model testing, I find that I only need to replace the downed grinder to maximize demand.
# Out:
# Constraint: TorqueMaster Demand, RHS = 500.0, slack = 0.0, Limits = (344.0, 1744.0, Shadow Price = 5.714285714285714)
# Constraint: CryoLock Demand, RHS = 1000.0, slack = 111.42857142857144, Limits = (888.5714285714286, inf, Shadow Price = 0.0)
# Constraint: Axial-Flex Demand, RHS = 300.0, slack = 0.0, Limits = (0.0, 1315.0, Shadow Price = 8.0)
# Constraint: HydroForge Demand, RHS = 300.0, slack = 0.0, Limits = (0.0, 1400.9523809523807, Shadow Price = 4.0)
# Constraint: ThermaCore Demand, RHS = 800.0, slack = 0.0, Limits = (540.0, 2873.3333333333335, Shadow Price = 8.428571428571429)
# Constraint: MagnoRail Demand, RHS = 200.0, slack = 0.0, Limits = (0.0, 808.4210526315788, Shadow Price = 7.285714285714286)
# Constraint: VibeShield Demand, RHS = 100.0, slack = 100.0, Limits = (0.0, inf, Shadow Price = 0.0)
# Constraint: G Time Constraint, RHS = 1152.0, slack = 0.0, Limits = (530.0, 1230.0, Shadow Price = 8.571428571428571)
# Constraint: VD Time Constraint, RHS = 768.0, slack = 330.2857142857142, Limits = (437.7142857142858, inf, Shadow Price = 0.0)
# Constraint: HD Time Constraint, RHS = 1152.0, slack = 812.0, Limits = (340.0, inf, Shadow Price = 0.0)
# Constraint: B Time Constraint, RHS = 384.0, slack = 231.34285714285716, Limits = (152.65714285714284, inf, Shadow Price = 0.0)
# Constraint: P Time Constraint, RHS = 384.0, slack = 341.0, Limits = (43.0, inf, Shadow Price = 0.0)

# %%
# Multi-period model

# Let's define our data as vectors and matrices.

# Iterators; We will use these later to build variables and constraints with loops.
products = ["TorqueMaster", "CryoLock", "Axial-Flex", "HydroForge", "ThermaCore", "MagnoRail", "VibeShield"]
months = ["January", "February", "March", "April", "May", "June"]
machines = ["Grinder", "Vertical Drill", "Horizontal Drill", "Borer", "Planer"]

# Used later for time constraints.
time_per_machine = 16 * 24

# Objective coefficients; We wil assign these to our products to form the objective function.
obj_coeffs = [10,6,8,4,11,9,3]

# Matrices

## The usage matrix encodes the amount of time required per machine per product, mapped across columns.
usage = np.array([
    [0.5,0.7,0,0,0.3,0.2,0.5], #Grinding
    [0.1,0.2,0,0.3,0,0.6,0], #Vertical Drilling 
    [0.2,0,0.8,0,0,0,0.6], #Horizontal Drilling
    [0.05,0.03,0,0.07,0.1,0,0.08], #Boring
    [0,0,0.01,0,0.05,0,0.05] #Planing
]) 

## The availability matrix displays the number of available machines as the total owned amount minus the predicted amount down for maintenance.

availability = np.array([
    [4-1, 2-0, 3-0, 1-0, 1-0], # January (1 Grinder down)
    [4-0, 2-0, 3-2, 1-0, 1-0], # February (2 Horiz. Drills down)
    [4-0, 2-0, 3-0, 1-0, 1-0], # March
    [4-0, 2-1, 3-0, 1-0, 1-0], # April (1 Vert. Drill down)
    [4-1, 2-1, 3-0, 1-0, 1-0], # May (1 Grinder, 1 Vert. Drill down)
    [4-0, 2-0, 3-1, 1-0, 1-0]  # June (1 Horiz. Drill down)
])

## Monthly capacity per machine type is calculated as the general time constraint multiplied by the number of available machines.

monthly_capacity = availability * time_per_machine

## The demand matrix encodes the demand per product per month.

demand = np.array([
    [500,1000,300,300,800,200,100], #January
    [600,500,200,0,400,300,150], #February
    [300,600,0,0,500,400,100], #March
    [200,300,400,500,200,0,100], #April
    [0,100,500,100,1000,300,0], #May
    [500,500,100,300,1100,500,60] #June
])

## The flag matrix is a convenient way to prevent the model from utili
flag = np.array([
    [0,0,0,0,0,0,0], #January
    [0,0,0,0,0,0,0], #Febraury
    #[0,0,0,0,0,0,0], #March if we had two borers 
    [1,1,0,1,1,0,1], #March
    [0,0,0,0,0,0,0], #April
    [0,0,0,0,0,0,0], #May
    [0,0,1,0,1,0,1] #June
    #[0,0,0,0,0,0,0] #June if we had two planers
])

# %%
# Create model
m_multi = gp.Model("Multiperiod Model")
m_multi.ModelSense = GRB.MAXIMIZE

# Decision variables: Products with objective coefficients
pvar_m = []
[pvar_m.append([m_multi.addVar(name = f'{products[i]}_{months[m]}', lb=0.0, obj=obj_coeffs[i]) for i in range(len(products))]) for m in range(len(months))]
m_multi.update()

# Decision variables: Storage with boundaries, which differ for the -1 month (initialization) and June, and have a cost of -0.50 for all intermediary months
# The initialization 'month', storage_init, prevents the model from using June storage to fulfill January's demand.
pvar_s = []
pvar_s.append([m_multi.addVar(name = f'{products[i]}_storage_init', lb=0.0, ub=0.0) for i in range(len(products))])
[pvar_s.append([m_multi.addVar(name = f'{products[i]}_{months[m]}_storage', lb=0.0, ub=100.0, obj=-0.50) for i in range(len(products))]) for m in range(len(months)-1)]
pvar_s.append([m_multi.addVar(name = f'{products[i]}_{months[-1]}_storage', lb=50.0, ub=50.0) for i in range(len(products))])
m_multi.update()

# Prevent sales beyond demand, prevent production when machines are down, and allow storage
for m in range(len(months)):
    for i in range(len(products)):
        sales_this_month = pvar_s[m][i] + pvar_m[m][i] - pvar_s[m+1][i]
        # This sales amount must be >= 0 and <= demand
        m_multi.addConstr(sales_this_month <= demand[m][i], name=f"Demand_{m}_{i}")
        m_multi.addConstr(sales_this_month >= 0, name=f"NoNegativeSales_{m}_{i}")
        
        if flag[m][i] == 1:
            m_multi.addConstr(pvar_m[m][i] == 0, name=f"Flagged_Month_{m}_Prod_{i}")

# Machine usage and time constraints, split across production for sales vs storage. This forces the model to consider overall production limits for both
# products produced for sales and products produced for storage.
for m in range(len(months)):
    for i in range(len(machines)):
        m_multi.addConstr(gp.quicksum(usage[i][p] * pvar_m[m][p] for p in range(len(products))) <= monthly_capacity[m][i])

m_multi.update()
m_multi.display()
m_multi.optimize()

# Print results
for m in range(len(months)):
    print(f'Production Schedule + Sold Storage for {months[m]}: ')
    for var in pvar_m[m]:
        print(f'    {var.VarName}: {var.X}')
    print(f'Storage Schedule for {months[m]}: ')
    for var in pvar_s[m+1]:
        print(f'    {var.VarName}: {var.X:0.2f}')
        
print(f'Optimal profit: ${m_multi.ObjVal:0.2f}')
# Out:
# Maximize
# 10.0 TorqueMaster_January + 6.0 CryoLock_January + 8.0 Axial-Flex_January
# + 4.0 HydroForge_January + 11.0 ThermaCore_January + 9.0 MagnoRail_January
# + 3.0 VibeShield_January + 10.0 TorqueMaster_February + 6.0 CryoLock_February + 8.0 Axial
# -Flex_February + 4.0 HydroForge_February + 11.0 ThermaCore_February
# + 9.0 MagnoRail_February + 3.0 VibeShield_February + 10.0 TorqueMaster_March
# + 6.0 CryoLock_March + 8.0 Axial-Flex_March + 4.0 HydroForge_March
# + 11.0 ThermaCore_March + 9.0 MagnoRail_March + 3.0 VibeShield_March
# + 10.0 TorqueMaster_April + 6.0 CryoLock_April + 8.0 Axial-Flex_April
# + 4.0 HydroForge_April + 11.0 ThermaCore_April + 9.0 MagnoRail_April
# + 3.0 VibeShield_April + 10.0 TorqueMaster_May + 6.0 CryoLock_May + 8.0 Axial-Flex_May
# + 4.0 HydroForge_May + 11.0 ThermaCore_May + 9.0 MagnoRail_May + 3.0 VibeShield_May
# + 10.0 TorqueMaster_June + 6.0 CryoLock_June + 8.0 Axial-Flex_June + 4.0 HydroForge_June
# + 11.0 ThermaCore_June + 9.0 MagnoRail_June + 3.0 VibeShield_June +
# -0.5 TorqueMaster_January_storage + -0.5 CryoLock_January_storage + -0.5 Axial
# -Flex_January_storage + -0.5 HydroForge_January_storage +
# -0.5 ThermaCore_January_storage + -0.5 MagnoRail_January_storage +
# -0.5 VibeShield_January_storage + -0.5 TorqueMaster_February_storage +
# -0.5 CryoLock_February_storage + -0.5 Axial-Flex_February_storage +
# -0.5 HydroForge_February_storage + -0.5 ThermaCore_February_storage +
# -0.5 MagnoRail_February_storage + -0.5 VibeShield_February_storage +
# -0.5 TorqueMaster_March_storage + -0.5 CryoLock_March_storage + -0.5 Axial
# -Flex_March_storage + -0.5 HydroForge_March_storage + -0.5 ThermaCore_March_storage +
# -0.5 MagnoRail_March_storage + -0.5 VibeShield_March_storage +
# -0.5 TorqueMaster_April_storage + -0.5 CryoLock_April_storage + -0.5 Axial
# -Flex_April_storage + -0.5 HydroForge_April_storage + -0.5 ThermaCore_April_storage +
# -0.5 MagnoRail_April_storage + -0.5 VibeShield_April_storage +
# -0.5 TorqueMaster_May_storage + -0.5 CryoLock_May_storage + -0.5 Axial-Flex_May_storage
# + -0.5 HydroForge_May_storage + -0.5 ThermaCore_May_storage + -0.5 MagnoRail_May_storage
# + -0.5 VibeShield_May_storage
# Subject To
# Demand_0_0: TorqueMaster_January + TorqueMaster_storage_init + -1.0
#  TorqueMaster_January_storage <= 500
# NoNegativeSales_0_0: TorqueMaster_January + TorqueMaster_storage_init + -1.0
#  TorqueMaster_January_storage >= 0
# Demand_0_1: CryoLock_January + CryoLock_storage_init + -1.0 CryoLock_January_storage <=
#  1000
# NoNegativeSales_0_1: CryoLock_January + CryoLock_storage_init + -1.0
#  CryoLock_January_storage >= 0
# Demand_0_2: Axial-Flex_January + Axial-Flex_storage_init + -1.0
#  Axial-Flex_January_storage <= 300
# NoNegativeSales_0_2: Axial-Flex_January + Axial-Flex_storage_init + -1.0
#  Axial-Flex_January_storage >= 0
# Demand_0_3: HydroForge_January + HydroForge_storage_init + -1.0
#  HydroForge_January_storage <= 300
# NoNegativeSales_0_3: HydroForge_January + HydroForge_storage_init + -1.0
#  HydroForge_January_storage >= 0
# Demand_0_4: ThermaCore_January + ThermaCore_storage_init + -1.0
#  ThermaCore_January_storage <= 800
# NoNegativeSales_0_4: ThermaCore_January + ThermaCore_storage_init + -1.0
#  ThermaCore_January_storage >= 0
# Demand_0_5: MagnoRail_January + MagnoRail_storage_init + -1.0 MagnoRail_January_storage
#  <= 200
# NoNegativeSales_0_5: MagnoRail_January + MagnoRail_storage_init + -1.0
#  MagnoRail_January_storage >= 0
# Demand_0_6: VibeShield_January + VibeShield_storage_init + -1.0
#  VibeShield_January_storage <= 100
# NoNegativeSales_0_6: VibeShield_January + VibeShield_storage_init + -1.0
#  VibeShield_January_storage >= 0
# Demand_1_0: TorqueMaster_February + TorqueMaster_January_storage + -1.0
#  TorqueMaster_February_storage <= 600
# NoNegativeSales_1_0: TorqueMaster_February + TorqueMaster_January_storage + -1.0
#  TorqueMaster_February_storage >= 0
# Demand_1_1: CryoLock_February + CryoLock_January_storage + -1.0
#  CryoLock_February_storage <= 500
# NoNegativeSales_1_1: CryoLock_February + CryoLock_January_storage + -1.0
#  CryoLock_February_storage >= 0
# Demand_1_2: Axial-Flex_February + Axial-Flex_January_storage + -1.0
#  Axial-Flex_February_storage <= 200
# NoNegativeSales_1_2: Axial-Flex_February + Axial-Flex_January_storage + -1.0
#  Axial-Flex_February_storage >= 0
# Demand_1_3: HydroForge_February + HydroForge_January_storage + -1.0
#  HydroForge_February_storage <= 0
# NoNegativeSales_1_3: HydroForge_February + HydroForge_January_storage + -1.0
#  HydroForge_February_storage >= 0
# Demand_1_4: ThermaCore_February + ThermaCore_January_storage + -1.0
#  ThermaCore_February_storage <= 400
# NoNegativeSales_1_4: ThermaCore_February + ThermaCore_January_storage + -1.0
#  ThermaCore_February_storage >= 0
# Demand_1_5: MagnoRail_February + MagnoRail_January_storage + -1.0
#  MagnoRail_February_storage <= 300
# NoNegativeSales_1_5: MagnoRail_February + MagnoRail_January_storage + -1.0
#  MagnoRail_February_storage >= 0
# Demand_1_6: VibeShield_February + VibeShield_January_storage + -1.0
#  VibeShield_February_storage <= 150
# NoNegativeSales_1_6: VibeShield_February + VibeShield_January_storage + -1.0
#  VibeShield_February_storage >= 0
# Demand_2_0: TorqueMaster_March + TorqueMaster_February_storage + -1.0
#  TorqueMaster_March_storage <= 300
# NoNegativeSales_2_0: TorqueMaster_March + TorqueMaster_February_storage + -1.0
#  TorqueMaster_March_storage >= 0
#   Flagged_Month_2_Prod_0: TorqueMaster_March = 0
# Demand_2_1: CryoLock_March + CryoLock_February_storage + -1.0 CryoLock_March_storage <=
#  600
# NoNegativeSales_2_1: CryoLock_March + CryoLock_February_storage + -1.0
#  CryoLock_March_storage >= 0
#   Flagged_Month_2_Prod_1: CryoLock_March = 0
# Demand_2_2: Axial-Flex_March + Axial-Flex_February_storage + -1.0
#  Axial-Flex_March_storage <= 0
# NoNegativeSales_2_2: Axial-Flex_March + Axial-Flex_February_storage + -1.0
#  Axial-Flex_March_storage >= 0
# Demand_2_3: HydroForge_March + HydroForge_February_storage + -1.0
#  HydroForge_March_storage <= 0
# NoNegativeSales_2_3: HydroForge_March + HydroForge_February_storage + -1.0
#  HydroForge_March_storage >= 0
#   Flagged_Month_2_Prod_3: HydroForge_March = 0
# Demand_2_4: ThermaCore_March + ThermaCore_February_storage + -1.0
#  ThermaCore_March_storage <= 500
# NoNegativeSales_2_4: ThermaCore_March + ThermaCore_February_storage + -1.0
#  ThermaCore_March_storage >= 0
#   Flagged_Month_2_Prod_4: ThermaCore_March = 0
# Demand_2_5: MagnoRail_March + MagnoRail_February_storage + -1.0 MagnoRail_March_storage
#  <= 400
# NoNegativeSales_2_5: MagnoRail_March + MagnoRail_February_storage + -1.0
#  MagnoRail_March_storage >= 0
# Demand_2_6: VibeShield_March + VibeShield_February_storage + -1.0
#  VibeShield_March_storage <= 100
# NoNegativeSales_2_6: VibeShield_March + VibeShield_February_storage + -1.0
#  VibeShield_March_storage >= 0
#   Flagged_Month_2_Prod_6: VibeShield_March = 0
# Demand_3_0: TorqueMaster_April + TorqueMaster_March_storage + -1.0
#  TorqueMaster_April_storage <= 200
# NoNegativeSales_3_0: TorqueMaster_April + TorqueMaster_March_storage + -1.0
#  TorqueMaster_April_storage >= 0
#   Demand_3_1: CryoLock_April + CryoLock_March_storage + -1.0 CryoLock_April_storage <= 300
# NoNegativeSales_3_1: CryoLock_April + CryoLock_March_storage + -1.0
#  CryoLock_April_storage >= 0
# Demand_3_2: Axial-Flex_April + Axial-Flex_March_storage + -1.0 Axial-Flex_April_storage
#  <= 400
# NoNegativeSales_3_2: Axial-Flex_April + Axial-Flex_March_storage + -1.0
#  Axial-Flex_April_storage >= 0
# Demand_3_3: HydroForge_April + HydroForge_March_storage + -1.0 HydroForge_April_storage
#  <= 500
# NoNegativeSales_3_3: HydroForge_April + HydroForge_March_storage + -1.0
#  HydroForge_April_storage >= 0
# Demand_3_4: ThermaCore_April + ThermaCore_March_storage + -1.0 ThermaCore_April_storage
#  <= 200
# NoNegativeSales_3_4: ThermaCore_April + ThermaCore_March_storage + -1.0
#  ThermaCore_April_storage >= 0
# Demand_3_5: MagnoRail_April + MagnoRail_March_storage + -1.0 MagnoRail_April_storage <=
#  0
# NoNegativeSales_3_5: MagnoRail_April + MagnoRail_March_storage + -1.0
#  MagnoRail_April_storage >= 0
# Demand_3_6: VibeShield_April + VibeShield_March_storage + -1.0 VibeShield_April_storage
#  <= 100
# NoNegativeSales_3_6: VibeShield_April + VibeShield_March_storage + -1.0
#  VibeShield_April_storage >= 0
# Demand_4_0: TorqueMaster_May + TorqueMaster_April_storage + -1.0
#  TorqueMaster_May_storage <= 0
# NoNegativeSales_4_0: TorqueMaster_May + TorqueMaster_April_storage + -1.0
#  TorqueMaster_May_storage >= 0
#   Demand_4_1: CryoLock_May + CryoLock_April_storage + -1.0 CryoLock_May_storage <= 100
# NoNegativeSales_4_1: CryoLock_May + CryoLock_April_storage + -1.0 CryoLock_May_storage
#  >= 0
# Demand_4_2: Axial-Flex_May + Axial-Flex_April_storage + -1.0 Axial-Flex_May_storage <=
#  500
# NoNegativeSales_4_2: Axial-Flex_May + Axial-Flex_April_storage + -1.0
#  Axial-Flex_May_storage >= 0
# Demand_4_3: HydroForge_May + HydroForge_April_storage + -1.0 HydroForge_May_storage <=
#  100
# NoNegativeSales_4_3: HydroForge_May + HydroForge_April_storage + -1.0
#  HydroForge_May_storage >= 0
# Demand_4_4: ThermaCore_May + ThermaCore_April_storage + -1.0 ThermaCore_May_storage <=
#  1000
# NoNegativeSales_4_4: ThermaCore_May + ThermaCore_April_storage + -1.0
#  ThermaCore_May_storage >= 0
#   Demand_4_5: MagnoRail_May + MagnoRail_April_storage + -1.0 MagnoRail_May_storage <= 300
# NoNegativeSales_4_5: MagnoRail_May + MagnoRail_April_storage + -1.0
#  MagnoRail_May_storage >= 0
#   Demand_4_6: VibeShield_May + VibeShield_April_storage + -1.0 VibeShield_May_storage <= 0
# NoNegativeSales_4_6: VibeShield_May + VibeShield_April_storage + -1.0
#  VibeShield_May_storage >= 0
# Demand_5_0: TorqueMaster_June + TorqueMaster_May_storage + -1.0
#  TorqueMaster_June_storage <= 500
# NoNegativeSales_5_0: TorqueMaster_June + TorqueMaster_May_storage + -1.0
#  TorqueMaster_June_storage >= 0
#   Demand_5_1: CryoLock_June + CryoLock_May_storage + -1.0 CryoLock_June_storage <= 500
# NoNegativeSales_5_1: CryoLock_June + CryoLock_May_storage + -1.0 CryoLock_June_storage
#  >= 0
# Demand_5_2: Axial-Flex_June + Axial-Flex_May_storage + -1.0 Axial-Flex_June_storage <=
#  100
# NoNegativeSales_5_2: Axial-Flex_June + Axial-Flex_May_storage + -1.0
#  Axial-Flex_June_storage >= 0
#   Flagged_Month_5_Prod_2: Axial-Flex_June = 0
# Demand_5_3: HydroForge_June + HydroForge_May_storage + -1.0 HydroForge_June_storage <=
#  300
# NoNegativeSales_5_3: HydroForge_June + HydroForge_May_storage + -1.0
#  HydroForge_June_storage >= 0
# Demand_5_4: ThermaCore_June + ThermaCore_May_storage + -1.0 ThermaCore_June_storage <=
#  1100
# NoNegativeSales_5_4: ThermaCore_June + ThermaCore_May_storage + -1.0
#  ThermaCore_June_storage >= 0
#   Flagged_Month_5_Prod_4: ThermaCore_June = 0
#   Demand_5_5: MagnoRail_June + MagnoRail_May_storage + -1.0 MagnoRail_June_storage <= 500
# NoNegativeSales_5_5: MagnoRail_June + MagnoRail_May_storage + -1.0
#  MagnoRail_June_storage >= 0
# Demand_5_6: VibeShield_June + VibeShield_May_storage + -1.0 VibeShield_June_storage <=
#  60
# NoNegativeSales_5_6: VibeShield_June + VibeShield_May_storage + -1.0
#  VibeShield_June_storage >= 0
#   Flagged_Month_5_Prod_6: VibeShield_June = 0
# R92: 0.5 TorqueMaster_January + 0.7 CryoLock_January + 0.3 ThermaCore_January + 0.2
#  MagnoRail_January + 0.5 VibeShield_January <= 1152
# R93: 0.1 TorqueMaster_January + 0.2 CryoLock_January + 0.3 HydroForge_January + 0.6
#  MagnoRail_January <= 768
#   R94: 0.2 TorqueMaster_January + 0.8 Axial-Flex_January + 0.6 VibeShield_January <= 1152
# R95: 0.05 TorqueMaster_January + 0.03 CryoLock_January + 0.07 HydroForge_January + 0.1
#  ThermaCore_January + 0.08 VibeShield_January <= 384
#   R96: 0.01 Axial-Flex_January + 0.05 ThermaCore_January + 0.05 VibeShield_January <= 384
# R97: 0.5 TorqueMaster_February + 0.7 CryoLock_February + 0.3 ThermaCore_February + 0.2
#  MagnoRail_February + 0.5 VibeShield_February <= 1536
# R98: 0.1 TorqueMaster_February + 0.2 CryoLock_February + 0.3 HydroForge_February + 0.6
#  MagnoRail_February <= 768
# R99: 0.2 TorqueMaster_February + 0.8 Axial-Flex_February + 0.6 VibeShield_February <=
#  384
# R100: 0.05 TorqueMaster_February + 0.03 CryoLock_February + 0.07 HydroForge_February +
#  0.1 ThermaCore_February + 0.08 VibeShield_February <= 384
# R101: 0.01 Axial-Flex_February + 0.05 ThermaCore_February + 0.05 VibeShield_February <=
#  384
# R102: 0.5 TorqueMaster_March + 0.7 CryoLock_March + 0.3 ThermaCore_March + 0.2
#  MagnoRail_March + 0.5 VibeShield_March <= 1536
# R103: 0.1 TorqueMaster_March + 0.2 CryoLock_March + 0.3 HydroForge_March + 0.6
#  MagnoRail_March <= 768
#   R104: 0.2 TorqueMaster_March + 0.8 Axial-Flex_March + 0.6 VibeShield_March <= 1152
# R105: 0.05 TorqueMaster_March + 0.03 CryoLock_March + 0.07 HydroForge_March + 0.1
#  ThermaCore_March + 0.08 VibeShield_March <= 384
#   R106: 0.01 Axial-Flex_March + 0.05 ThermaCore_March + 0.05 VibeShield_March <= 384
# R107: 0.5 TorqueMaster_April + 0.7 CryoLock_April + 0.3 ThermaCore_April + 0.2
#  MagnoRail_April + 0.5 VibeShield_April <= 1536
# R108: 0.1 TorqueMaster_April + 0.2 CryoLock_April + 0.3 HydroForge_April + 0.6
#  MagnoRail_April <= 384
#   R109: 0.2 TorqueMaster_April + 0.8 Axial-Flex_April + 0.6 VibeShield_April <= 1152
# R110: 0.05 TorqueMaster_April + 0.03 CryoLock_April + 0.07 HydroForge_April + 0.1
#  ThermaCore_April + 0.08 VibeShield_April <= 384
#   R111: 0.01 Axial-Flex_April + 0.05 ThermaCore_April + 0.05 VibeShield_April <= 384
# R112: 0.5 TorqueMaster_May + 0.7 CryoLock_May + 0.3 ThermaCore_May + 0.2 MagnoRail_May
#  + 0.5 VibeShield_May <= 1152
# R113: 0.1 TorqueMaster_May + 0.2 CryoLock_May + 0.3 HydroForge_May + 0.6 MagnoRail_May
#  <= 384
#   R114: 0.2 TorqueMaster_May + 0.8 Axial-Flex_May + 0.6 VibeShield_May <= 1152
# R115: 0.05 TorqueMaster_May + 0.03 CryoLock_May + 0.07 HydroForge_May + 0.1
#  ThermaCore_May + 0.08 VibeShield_May <= 384
#   R116: 0.01 Axial-Flex_May + 0.05 ThermaCore_May + 0.05 VibeShield_May <= 384
# R117: 0.5 TorqueMaster_June + 0.7 CryoLock_June + 0.3 ThermaCore_June + 0.2
#  MagnoRail_June + 0.5 VibeShield_June <= 1536
# R118: 0.1 TorqueMaster_June + 0.2 CryoLock_June + 0.3 HydroForge_June + 0.6
#  MagnoRail_June <= 768
#   R119: 0.2 TorqueMaster_June + 0.8 Axial-Flex_June + 0.6 VibeShield_June <= 768
# R120: 0.05 TorqueMaster_June + 0.03 CryoLock_June + 0.07 HydroForge_June + 0.1
#  ThermaCore_June + 0.08 VibeShield_June <= 384
#   R121: 0.01 Axial-Flex_June + 0.05 ThermaCore_June + 0.05 VibeShield_June <= 384
# Bounds
#   TorqueMaster_storage_init = 0
#   CryoLock_storage_init = 0
#   Axial-Flex_storage_init = 0
#   HydroForge_storage_init = 0
#   ThermaCore_storage_init = 0
#   MagnoRail_storage_init = 0
#   VibeShield_storage_init = 0
#   0 <= TorqueMaster_January_storage <= 100
#   0 <= CryoLock_January_storage <= 100
#   0 <= Axial-Flex_January_storage <= 100
#   0 <= HydroForge_January_storage <= 100
#   0 <= ThermaCore_January_storage <= 100
#   0 <= MagnoRail_January_storage <= 100
#   0 <= VibeShield_January_storage <= 100
#   0 <= TorqueMaster_February_storage <= 100
#   0 <= CryoLock_February_storage <= 100
#   0 <= Axial-Flex_February_storage <= 100
#   0 <= HydroForge_February_storage <= 100
#   0 <= ThermaCore_February_storage <= 100
#   0 <= MagnoRail_February_storage <= 100
#   0 <= VibeShield_February_storage <= 100
#   0 <= TorqueMaster_March_storage <= 100
#   0 <= CryoLock_March_storage <= 100
#   0 <= Axial-Flex_March_storage <= 100
#   0 <= HydroForge_March_storage <= 100
#   0 <= ThermaCore_March_storage <= 100
#   0 <= MagnoRail_March_storage <= 100
#   0 <= VibeShield_March_storage <= 100
#   0 <= TorqueMaster_April_storage <= 100
#   0 <= CryoLock_April_storage <= 100
#   0 <= Axial-Flex_April_storage <= 100
#   0 <= HydroForge_April_storage <= 100
#   0 <= ThermaCore_April_storage <= 100
#   0 <= MagnoRail_April_storage <= 100
#   0 <= VibeShield_April_storage <= 100
#   0 <= TorqueMaster_May_storage <= 100
#   0 <= CryoLock_May_storage <= 100
#   0 <= Axial-Flex_May_storage <= 100
#   0 <= HydroForge_May_storage <= 100
#   0 <= ThermaCore_May_storage <= 100
#   0 <= MagnoRail_May_storage <= 100
#   0 <= VibeShield_May_storage <= 100
#   TorqueMaster_June_storage = 50
#   CryoLock_June_storage = 50
#   Axial-Flex_June_storage = 50
#   HydroForge_June_storage = 50
#   ThermaCore_June_storage = 50
#   MagnoRail_June_storage = 50
#   VibeShield_June_storage = 50
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-12800H, instruction set [SSE2|AVX|AVX2]
# Thread count: 14 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 122 rows, 91 columns and 380 nonzeros
# Model fingerprint: 0x91a3d44b
# Coefficient statistics:
#   Matrix range     [1e-02, 1e+00]
#   Objective range  [5e-01, 1e+01]
#   Bounds range     [5e+01, 1e+02]
#   RHS range        [6e+01, 2e+03]
# Presolve removed 117 rows and 78 columns
# Presolve time: 0.01s
# Presolved: 5 rows, 16 columns, 21 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0770286e+05   3.299124e+02   0.000000e+00      0s
# Extra simplex iterations after uncrush: 7
#       10    9.6440179e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 10 iterations and 0.01 seconds (0.00 work units)
# C:\Users\harri\AppData\Local\Temp\ipykernel_26228\1358605966.py:36: DeprecationWarning: Model.display() is deprecated
#   m_multi.display()
# Optimal objective  9.644017857e+04
# Production Schedule + Sold Storage for January:
#     TorqueMaster_January: 500.0
#     CryoLock_January: 888.5714285714287
#     Axial-Flex_January: 382.5
#     HydroForge_January: 300.0
#     ThermaCore_January: 800.0
#     MagnoRail_January: 200.0
#     VibeShield_January: 0.0
# Storage Schedule for January:
#     TorqueMaster_January_storage: 0.00
#     CryoLock_January_storage: 0.00
#     Axial-Flex_January_storage: 82.50
#     HydroForge_January_storage: 0.00
#     ThermaCore_January_storage: 0.00
#     MagnoRail_January_storage: 0.00
#     VibeShield_January_storage: 0.00
# Production Schedule + Sold Storage for February:
#     TorqueMaster_February: 700.0
#     CryoLock_February: 600.0
#     Axial-Flex_February: 117.5
#     HydroForge_February: 0.0
#     ThermaCore_February: 500.0
#     MagnoRail_February: 300.0
#     VibeShield_February: 250.0
# Storage Schedule for February:
#     TorqueMaster_February_storage: 100.00
#     CryoLock_February_storage: 100.00
#     Axial-Flex_February_storage: 0.00
#     HydroForge_February_storage: 0.00
#     ThermaCore_February_storage: 100.00
#     MagnoRail_February_storage: 0.00
#     VibeShield_February_storage: 100.00
# Production Schedule + Sold Storage for March:
#     TorqueMaster_March: 0.0
#     CryoLock_March: 0.0
#     Axial-Flex_March: 0.0
#     HydroForge_March: 0.0
#     ThermaCore_March: 0.0
#     MagnoRail_March: 400.0
#     VibeShield_March: 0.0
# Storage Schedule for March:
#     TorqueMaster_March_storage: 0.00
#     CryoLock_March_storage: 0.00
#     Axial-Flex_March_storage: 0.00
#     HydroForge_March_storage: 0.00
#     ThermaCore_March_storage: 0.00
#     MagnoRail_March_storage: 0.00
#     VibeShield_March_storage: 0.00
# Production Schedule + Sold Storage for April:
#     TorqueMaster_April: 200.0
#     CryoLock_April: 300.0
#     Axial-Flex_April: 400.0
#     HydroForge_April: 500.0
#     ThermaCore_April: 200.0
#     MagnoRail_April: 0.0
#     VibeShield_April: 100.0
# Storage Schedule for April:
#     TorqueMaster_April_storage: 0.00
#     CryoLock_April_storage: 0.00
#     Axial-Flex_April_storage: 0.00
#     HydroForge_April_storage: 0.00
#     ThermaCore_April_storage: 0.00
#     MagnoRail_April_storage: 0.00
#     VibeShield_April_storage: 0.00
# Production Schedule + Sold Storage for May:
#     TorqueMaster_May: 0.0
#     CryoLock_May: 100.0
#     Axial-Flex_May: 600.0
#     HydroForge_May: 100.0
#     ThermaCore_May: 1100.0
#     MagnoRail_May: 300.0
#     VibeShield_May: 100.0
# Storage Schedule for May:
#     TorqueMaster_May_storage: 0.00
#     CryoLock_May_storage: 0.00
#     Axial-Flex_May_storage: 100.00
#     HydroForge_May_storage: 0.00
#     ThermaCore_May_storage: 100.00
#     MagnoRail_May_storage: 0.00
#     VibeShield_May_storage: 100.00
# Production Schedule + Sold Storage for June:
#     TorqueMaster_June: 550.0
#     CryoLock_June: 550.0
#     Axial-Flex_June: 0.0
#     HydroForge_June: 350.0
#     ThermaCore_June: 0.0
#     MagnoRail_June: 550.0
#     VibeShield_June: 0.0
# Storage Schedule for June:
#     TorqueMaster_June_storage: 50.00
#     CryoLock_June_storage: 50.00
#     Axial-Flex_June_storage: 50.00
#     HydroForge_June_storage: 50.00
#     ThermaCore_June_storage: 50.00
#     MagnoRail_June_storage: 50.00
#     VibeShield_June_storage: 50.00
# Optimal profit: $96440.18
